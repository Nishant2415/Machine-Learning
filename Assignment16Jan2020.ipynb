# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading dataset

# %%
bank = pd.read_csv('https://github.com/Nishant2415/Machine-Learning/raw/master/bank_updated.csv')

# %%
bank
# Out:
#       age            job  marital  education default      balance housing  \
# 0      30     unemployed  married    primary      no  1787.000000      no
# 2      33       services  married  secondary      no  4789.000000     yes
# 3      35     management   single   tertiary      no  1350.000000     yes
# 4      30     management  married   tertiary      no  1476.000000     yes
# 6      59    blue-collar  married  secondary      no  1418.140057     yes
# ...   ...            ...      ...        ...     ...          ...     ...
# 4536   33       services  married  secondary      no  -333.000000     yes
# 4537   57  self-employed  married   tertiary     yes -3313.000000     yes
# 4538   57     technician  married  secondary      no   295.000000      no
# 4539   28    blue-collar  married  secondary      no  1137.000000      no
# 4540   44   entrepreneur   single   tertiary      no  1136.000000     yes
#
#      loan   contact day month  duration  campaign  pdays previous poutcome   y
# 0      no  cellular  19   oct      79.0         1     -1        0  unknown  no
# 2     yes  cellular  11   may     220.0         1    339        4  failure  no
# 3      no  cellular  16   apr     185.0         1    330        1  failure  no
# 4     yes   unknown   3   jun     199.0         4     -1        0  unknown  no
# 6      no   unknown   5   may     226.0         1     -1        0  unknown  no
# ...   ...       ...  ..   ...       ...       ...    ...      ...      ...  ..
# 4536   no  cellular  30   jul     329.0         5     -1        0  unknown  no
# 4537  yes   unknown   9   may     153.0         1     -1        0  unknown  no
# 4538   no  cellular  19   aug     151.0        11     -1        0  unknown  no
# 4539   no  cellular   6   feb     129.0         4    211        3    other  no
# 4540  yes  cellular   3   apr     345.0         2    249        7    other  no
#
# [4523 rows x 17 columns]

# %% [markdown]
# ### Check and count any null data is present in the data set

# %%
bank.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     2
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            1
# dtype: int64

# %% [markdown]
# ### Replace null balance by the average

# %%
bank['balance'] = bank['balance'].replace('yes',0)
bank['balance'] = bank['balance'].replace(np.nan,0)

# %% [markdown]
# Type casting the balance column

# %%
bank['balance'] = bank['balance'].astype(int)

# %% [markdown]
# Find mean before

# %%
mean = bank['balance'].mean()
mean
# Out:
# 1418.140057256111

# %%
bank['balance'] = bank['balance'].replace(0,mean)

# %% [markdown]
# Find mean after

# %%
bank['balance'].mean()
# Out:
# 1534.3463543377159

# %% [markdown]
# ### Check and remove the duplicate row, by preserving the last row

# %%
bank.drop_duplicates()
# Out:
#       age            job  marital  education default      balance housing  \
# 0      30     unemployed  married    primary      no  1787.000000      no
# 2      33       services  married  secondary      no  4789.000000     yes
# 3      35     management   single   tertiary      no  1350.000000     yes
# 4      30     management  married   tertiary      no  1476.000000     yes
# 6      59    blue-collar  married  secondary      no  1418.140057     yes
# ...   ...            ...      ...        ...     ...          ...     ...
# 4536   33       services  married  secondary      no  -333.000000     yes
# 4537   57  self-employed  married   tertiary     yes -3313.000000     yes
# 4538   57     technician  married  secondary      no   295.000000      no
# 4539   28    blue-collar  married  secondary      no  1137.000000      no
# 4540   44   entrepreneur   single   tertiary      no  1136.000000     yes
#
#      loan   contact day month  duration  campaign  pdays previous poutcome   y
# 0      no  cellular  19   oct      79.0         1     -1        0  unknown  no
# 2     yes  cellular  11   may     220.0         1    339        4  failure  no
# 3      no  cellular  16   apr     185.0         1    330        1  failure  no
# 4     yes   unknown   3   jun     199.0         4     -1        0  unknown  no
# 6      no   unknown   5   may     226.0         1     -1        0  unknown  no
# ...   ...       ...  ..   ...       ...       ...    ...      ...      ...  ..
# 4536   no  cellular  30   jul     329.0         5     -1        0  unknown  no
# 4537  yes   unknown   9   may     153.0         1     -1        0  unknown  no
# 4538   no  cellular  19   aug     151.0        11     -1        0  unknown  no
# 4539   no  cellular   6   feb     129.0         4    211        3    other  no
# 4540  yes  cellular   3   apr     345.0         2    249        7    other  no
#
# [4523 rows x 17 columns]

# %% [markdown]
# ### Find the unique types of job in the data set

# %%
bank['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %% [markdown]
# ### Count the total clients based on their marital status

# %%
bank['marital'].value_counts()
# Out:
# married      2797
# single       1197
# divorced      528
# secondary       1
# Name: marital, dtype: int64

# %% [markdown]
# ### Drop the column 'loan'

# %%
bank.drop('loan', axis=1)
# Out:
#       age            job  marital  education default      balance housing  \
# 0      30     unemployed  married    primary      no  1787.000000      no
# 2      33       services  married  secondary      no  4789.000000     yes
# 3      35     management   single   tertiary      no  1350.000000     yes
# 4      30     management  married   tertiary      no  1476.000000     yes
# 6      59    blue-collar  married  secondary      no  1418.140057     yes
# ...   ...            ...      ...        ...     ...          ...     ...
# 4536   33       services  married  secondary      no  -333.000000     yes
# 4537   57  self-employed  married   tertiary     yes -3313.000000     yes
# 4538   57     technician  married  secondary      no   295.000000      no
# 4539   28    blue-collar  married  secondary      no  1137.000000      no
# 4540   44   entrepreneur   single   tertiary      no  1136.000000     yes
#
#        contact day month  duration  campaign  pdays previous poutcome   y
# 0     cellular  19   oct      79.0         1     -1        0  unknown  no
# 2     cellular  11   may     220.0         1    339        4  failure  no
# 3     cellular  16   apr     185.0         1    330        1  failure  no
# 4      unknown   3   jun     199.0         4     -1        0  unknown  no
# 6      unknown   5   may     226.0         1     -1        0  unknown  no
# ...        ...  ..   ...       ...       ...    ...      ...      ...  ..
# 4536  cellular  30   jul     329.0         5     -1        0  unknown  no
# 4537   unknown   9   may     153.0         1     -1        0  unknown  no
# 4538  cellular  19   aug     151.0        11     -1        0  unknown  no
# 4539  cellular   6   feb     129.0         4    211        3    other  no
# 4540  cellular   3   apr     345.0         2    249        7    other  no
#
# [4523 rows x 16 columns]
