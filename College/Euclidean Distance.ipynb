# %%
import pandas as pd
import numpy as nm
from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer

data = pd.read_csv("c:/Users/hp/Desktop/Mayur ML with python/Datasets/Heart Disease Dataset.csv")
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean    54.432258    0.683871    0.970968  131.606452  245.664516    0.151613
# std      9.056114    0.465716    1.040815   17.466379   51.460517    0.359225
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.500000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     0.503226  149.764516    0.325806    1.779032    1.393548    0.729032
# ...

# %%
import numpy as np
from scipy.spatial import distance
p1 =  np.array(data.iloc[ :, 1:2]).ravel()
p2 =  np.array(data.iloc[ :, 2:3]).ravel()
d1 = distance.euclidean(p1, p2)
print("Euclidean distance: ",d1)
# Out:
# Euclidean distance:  21.0
