# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.covariance import EllipticEnvelope
from sklearn.decomposition import PCA

# %% [markdown]
# ### Load the data set for Bike Rentals

# %%
bike = pd.read_csv('https://github.com/Nishant2415/Machine-Learning/raw/master/Dataset/bike_updated.csv')
bike.head(20)
# Out:
#     season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0        1        0           0        1   9.84  14.395        81     0.0000
# 1        1        0           0        1   9.02  13.635        80     0.0000
# 2        1        0           0        1   9.02  13.635        80     0.0000
# 3        1        0           0        1   9.84  14.395        75     0.0000
# 4        1        0           0        1   9.84  14.395        75     0.0000
# 5        1        0           0        2   9.84  12.880        75     6.0032
# 6        1        0           0        1   9.02  13.635        80     0.0000
# 7        1        0           0        1   8.20  12.880        86     0.0000
# 8        1        0           0        1   9.84  14.395        75     0.0000
# 9        1        0           0        1  13.12  17.425        76     0.0000
# 10       1        0           0        1  15.58  19.695        76    16.9979
# 11       1        0           0        1  14.76  16.665        81    19.0012
# 12       1        0           0        1  17.22  21.210        77    19.0012
# 13       1        0           0        2  18.86  22.725        72    19.9995
# 14       1        0           0        2  18.86  22.725        72    19.0012
# 15       1        0           0        2  18.04  21.970        77    19.9995
# 16       1        0           0        2  17.22  21.210        82    19.9995
# 17       1        0           0        2  18.04  21.970        82    19.0012
# 18       1        0           0        3  17.22  21.210        88    16.9979
# 19       1        0           0        3  17.22  21.210        88    16.9979
#
#     casual  registered  count
# 0        3          13     16
# 1        8          32     40
# 2        5          27     32
# 3        3          10     13
# 4        0           1      1
# 5        0           1      1
# 6        2           0      2
# 7        1           2      3
# 8        1           7      8
# 9        8           6     14
# 10      12          24     36
# 11      26          30     56
# 12      29          55     84
# 13      47          47     94
# 14      35          71    106
# 15      40          70    110
# 16      41          52     93
# 17      15          52     67
# 18       9          26     35
# 19       6          31     37

# %% [markdown]
# ### For season, convert the categorial data into numeric value using following:season (1:springer, 2:summer, 3:fall, 4:winter)

# %%
temp = {"season":{1:'springer',2:'summer',3:'fall',4:'winter'}}
print(temp)
bike.replace(temp,inplace=True)
bike
# Out:
# {'season': {1: 'springer', 2: 'summer', 3: 'fall', 4: 'winter'}}
#          season  holiday  workingday  weather   temp   atemp  humidity  \
# 0      springer        0           0        1   9.84  14.395        81
# 1      springer        0           0        1   9.02  13.635        80
# 2      springer        0           0        1   9.02  13.635        80
# 3      springer        0           0        1   9.84  14.395        75
# 4      springer        0           0        1   9.84  14.395        75
# ...         ...      ...         ...      ...    ...     ...       ...
# 10881    winter        0           1        1  15.58  19.695        50
# 10882    winter        0           1        1  14.76  17.425        57
# 10883    winter        0           1        1  13.94  15.910        61
# 10884    winter        0           1        1  13.94  17.425        61
# 10885    winter        0           1        1  13.12  16.665        66
#
#        windspeed  casual  registered  count
# 0         0.0000       3          13     16
# 1         0.0000       8          32     40
# 2         0.0000       5          27     32
# 3         0.0000       3          10     13
# 4         0.0000       0           1      1
# ...          ...     ...         ...    ...
# 10881    26.0027       7         329    336
# 10882    15.0013      10         231    241
# 10883    15.0013       4         164    168
# 10884     6.0032      12         117    129
# 10885     8.9981       4          84     88
#
# [10886 rows x 11 columns]

# %% [markdown]
# ### Scale the count of casual users in the range of 1 to 5

# %%
bike_casual = np.array(bike['casual']).reshape(-1,1)
minmax_scale = preprocessing.MinMaxScaler(feature_range=[1,5])
scaled_feature = minmax_scale.fit_transform(bike_casual)
scaled_feature
# Out:
# array([[1.03269755],
#        [1.08719346],
#        [1.05449591],
#        ...,
#        [1.04359673],
#        [1.13079019],
#        [1.04359673]])

# %% [markdown]
# ### Scale the count of registered users with variance as 1 and mean as 0

# %%
bike_registered = np.array(bike['registered']).reshape(-1,1)
std_scaler = preprocessing.StandardScaler()
standarized = std_scaler.fit_transform(bike_registered)
standarized
# Out:
# array([[-0.94385353],
#        [-0.81805246],
#        [-0.851158  ],
#        ...,
#        [ 0.05593396],
#        [-0.25525818],
#        [-0.47375478]])

# %% [markdown]
# ### Find the outliers with the contamination as 0.2

# %%
outlier_detector = EllipticEnvelope(contamination = 0.2)
outlier_detector.fit(np.array(bike['registered']).reshape(-1,1))
pre = outlier_detector.predict(np.array(bike['registered']).reshape(-1,1))
np.where(pre==-1)
# Out:
# (array([  813,   822,   846, ..., 10879, 10880, 10881], dtype=int64),)

# %% [markdown]
# ### Convert the humidity into binary from the discrete value. If the humidity is below 0.5, it should be 0 else 1

# %%
humidity = np.where(bike['humidity']<0.5,0,1)
humidity
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# ### Classify the column of windspeed intodifferent classes based on the value. The bins should be 0.25,0.50,0.75

# %%
bike['windspeed_bins'] = pd.cut(bike['windspeed'], [0,25,50,75])
bike.head(20)
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0   springer        0           0        1   9.84  14.395        81
# 1   springer        0           0        1   9.02  13.635        80
# 2   springer        0           0        1   9.02  13.635        80
# 3   springer        0           0        1   9.84  14.395        75
# 4   springer        0           0        1   9.84  14.395        75
# 5   springer        0           0        2   9.84  12.880        75
# 6   springer        0           0        1   9.02  13.635        80
# 7   springer        0           0        1   8.20  12.880        86
# 8   springer        0           0        1   9.84  14.395        75
# 9   springer        0           0        1  13.12  17.425        76
# 10  springer        0           0        1  15.58  19.695        76
# 11  springer        0           0        1  14.76  16.665        81
# 12  springer        0           0        1  17.22  21.210        77
# 13  springer        0           0        2  18.86  22.725        72
# 14  springer        0           0        2  18.86  22.725        72
# 15  springer        0           0        2  18.04  21.970        77
# 16  springer        0           0        2  17.22  21.210        82
# 17  springer        0           0        2  18.04  21.970        82
# 18  springer        0           0        3  17.22  21.210        88
# 19  springer        0           0        3  17.22  21.210        88
#
#     windspeed  casual  registered  count windspeed_bins
# 0      0.0000       3          13     16            NaN
# 1      0.0000       8          32     40            NaN
# 2      0.0000       5          27     32            NaN
# 3      0.0000       3          10     13            NaN
# 4      0.0000       0           1      1            NaN
# 5      6.0032       0           1      1    (0.0, 25.0]
# 6      0.0000       2           0      2            NaN
# 7      0.0000       1           2      3            NaN
# 8      0.0000       1           7      8            NaN
# 9      0.0000       8           6     14            NaN
# 10    16.9979      12          24     36    (0.0, 25.0]
# 11    19.0012      26          30     56    (0.0, 25.0]
# 12    19.0012      29          55     84    (0.0, 25.0]
# 13    19.9995      47          47     94    (0.0, 25.0]
# 14    19.0012      35          71    106    (0.0, 25.0]
# 15    19.9995      40          70    110    (0.0, 25.0]
# 16    19.9995      41          52     93    (0.0, 25.0]
# 17    19.0012      15          52     67    (0.0, 25.0]
# 18    16.9979       9          26     35    (0.0, 25.0]
# 19    16.9979       6          31     37    (0.0, 25.0]

# %% [markdown]
# ### Apply PCA to last 9 attributes and engineer it to 2 attributes

# %%
bike_pca = bike.drop(['season', 'holiday', 'windspeed_bins'],axis=1)
bike_pca
# Out:
#        workingday  weather   temp   atemp  humidity  windspeed  casual  \
# 0               0        1   9.84  14.395        81     0.0000       3
# 1               0        1   9.02  13.635        80     0.0000       8
# 2               0        1   9.02  13.635        80     0.0000       5
# 3               0        1   9.84  14.395        75     0.0000       3
# 4               0        1   9.84  14.395        75     0.0000       0
# ...           ...      ...    ...     ...       ...        ...     ...
# 10881           1        1  15.58  19.695        50    26.0027       7
# 10882           1        1  14.76  17.425        57    15.0013      10
# 10883           1        1  13.94  15.910        61    15.0013       4
# 10884           1        1  13.94  17.425        61     6.0032      12
# 10885           1        1  13.12  16.665        66     8.9981       4
#
#        registered  count
# 0              13     16
# 1              32     40
# 2              27     32
# 3              10     13
# 4               1      1
# ...           ...    ...
# 10881         329    336
# 10882         231    241
# 10883         164    168
# 10884         117    129
# 10885          84     88
#
# [10886 rows x 9 columns]

# %%
min_max_scaler = preprocessing.MinMaxScaler(feature_range=[0, 1])
scaler = min_max_scaler.fit_transform(bike_pca)
pca = PCA(n_components=0.99)
features_pca = pca.fit_transform(scaler)

# %% [markdown]
# ### Compare the total number of attributes before PCA and after PCA

# %%
print('Original features: ',bike_pca.shape[1])
print('Reduced features: ',features_pca.shape[1])
# Out:
# Original features:  9
# Reduced features:  7
